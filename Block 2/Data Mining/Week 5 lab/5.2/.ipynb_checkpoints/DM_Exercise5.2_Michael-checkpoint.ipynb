# %% [markdown]
# # Data Mining: Exercise 5.2 (All images analysis)
# Michael Quinlan
# SN: 6901824

# %% [markdown]
# ## **Research Question**
# Can we predict the popularity of a movie (i.e., the IMDB rating of a movie) solely on the basis of its poster?

# %%
# load all needed dependencies and libraries
# !pip install wget
import io
import os
import cv2
import wget
import urllib
#import webcolors
import colorgram
import numpy as np
import pandas as pd
import matplotlib as mpl
import tensorflow_hub as hub
from tqdm.notebook import tqdm
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
from matplotlib.colors import to_hex
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
# %config InlineBackend.figure_format='retina'

# %%
# change working directory and define path to movie poster images stored on local drive

os.chdir(r"C:\DMTIV\Modules\Week5Images\output")
ds_path = r'C:\DMTIV\Modules\Week 5 Images_Video\MovieGenre.csv'

# %%
# define a function to extract a sample of 500 movie poster images from local drive and
# creates and returns a dataframe to store metadata on movie posters

"""
Input: file path to .csv file with stored images of movie posters
Output: dataframe containing metadata on images of movie posters
"""

def get_movie_poster_sample(csv_path, output_dir, sample_size=500):
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)
    df = pd.read_csv(csv_path, sep=',', engine='python').dropna()
    sample = df.sample(sample_size, random_state=42)
    def_rows = []
    output_paths = []
    for row in tqdm(sample.itertuples(), total=sample_size):
        poster = row.Poster
        poster = poster[:poster.rfind('@')]
        poster_high_res = poster + '@._V1_FMjpg_UX500_.jpg'
        try:
            output_path = os.path.join(output_dir, str(row.imdbId) + '.jpg')
            if not os.path.isfile(output_path): # check to see if file exists
                urllib.request.urlretrieve(poster_high_res, output_path) # go to url to retrieve poster
        except:
            continue
        output_paths.append(output_path)
        def_rows.append(row)
    final_sample_df = pd.DataFrame(def_rows)
    final_sample_df['Path'] = output_paths
    final_sample_df = final_sample_df.rename(columns={'_4': 'IMDB_rating', '_2': 'Uri'})
    return final_sample_df

# %%
# call the function to retrieve movie poster images from local drive and store in dataframe

movie_poster_df = get_movie_poster_sample(ds_path, r'C:\DMTIV\Modules\Week5Images\MoviePosters')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=500.0), HTML(value='')))

# %%
# define a function that retrieves image from local drive

def load_image_from_path(image_path, target_size=None, color_mode='rgb'):
    pil_image = image.load_img(image_path, 
                               target_size=target_size,
                            color_mode=color_mode)
    return image.img_to_array(pil_image)

# %%
# extract movie titles from dataframe

"""
input: movie data frame, title column
output: list of movie names for each movie poster image
"""
movie_titles = []

for path in range(0, len(movie_poster_df)): # iterate over all rows in movie dataframe
    movie_title = movie_poster_df.Title[path] # extract movie titles
    movie_titles_split = movie_title.split("(") # split title from date
    movie_titles.append(movie_titles_split[0]) # store titles in list
# Out:
# ['The Dirty Dozen: The Fatal Mission ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties "]
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special "]
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's "]
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain "]
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ', 'VipÌ¬re au poing ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ', 'VipÌ¬re au poing ', 'Hour of the Gun ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ', 'VipÌ¬re au poing ', 'Hour of the Gun ', 'Hansel & Gretel ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ', 'VipÌ¬re au poing ', 'Hour of the Gun ', 'Hansel & Gretel ', 'Oy Vey! My Son Is Gay!! ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ', 'VipÌ¬re au poing ', 'Hour of the Gun ', 'Hansel & Gretel ', 'Oy Vey! My Son Is Gay!! ', 'Oslo, 31. august ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ', 'VipÌ¬re au poing ', 'Hour of the Gun ', 'Hansel & Gretel ', 'Oy Vey! My Son Is Gay!! ', 'Oslo, 31. august ', 'Love Me ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ', 'VipÌ¬re au poing ', 'Hour of the Gun ', 'Hansel & Gretel ', 'Oy Vey! My Son Is Gay!! ', 'Oslo, 31. august ', 'Love Me ', 'El malvado Carabel ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ', 'VipÌ¬re au poing ', 'Hour of the Gun ', 'Hansel & Gretel ', 'Oy Vey! My Son Is Gay!! ', 'Oslo, 31. august ', 'Love Me ', 'El malvado Carabel ', 'Der Clown ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ', 'VipÌ¬re au poing ', 'Hour of the Gun ', 'Hansel & Gretel ', 'Oy Vey! My Son Is Gay!! ', 'Oslo, 31. august ', 'Love Me ', 'El malvado Carabel ', 'Der Clown ', 'Licks ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ', 'VipÌ¬re au poing ', 'Hour of the Gun ', 'Hansel & Gretel ', 'Oy Vey! My Son Is Gay!! ', 'Oslo, 31. august ', 'Love Me ', 'El malvado Carabel ', 'Der Clown ', 'Licks ', 'Chan Is Missing ']
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ', 'VipÌ¬re au poing ', 'Hour of the Gun ', 'Hansel & Gretel ', 'Oy Vey! My Son Is Gay!! ', 'Oslo, 31. august ', 'Love Me ', 'El malvado Carabel ', 'Der Clown ', 'Licks ', 'Chan Is Missing ', 'The Big Blue ']
# ...
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ', 'VipÌ¬re au poing ', 'Hour of the Gun ', 'Hansel & Gretel ', 'Oy Vey! My Son Is Gay!! ', 'Oslo, 31. august ', 'Love Me ', 'El malvado Carabel ', 'Der Clown ', 'Licks ', 'Chan Is Missing ', 'The Big Blue ', 'Madame Bovary ', 'Borrowed Hearts ', 'The Quiet Room ', 'I 2 pompieri ', "There's Something Wrong with Aunt Diane ", 'No One Dies in Lily Dale ', 'Ernest Goes to Jail ', 'Suffragette ', 'Andron ', 'Sweet Revenge ', 'No Time for Comedy ', 'Subspecies ', 'Mesrine Part 2: Public Enemy #1 ', 'Sparrows Dance ', 'Askari ', 'I Want to Marry Ryan Banks ', 'Human Highway ', 'O.S.S. ', "Fool's Gold ", 'The River and Death ', 'The Case of the Velvet Claws ', 'Dog Park ', 'Tarzan in Manhattan ', 'Marilena de la P7 ', 'Body Language ', 'The Beast from 20,000 Fathoms ', 'The Match ', 'Dance Me Outside ', 'Huang feihong zhi yingxiong you meng ', 'Mosquito Squadron ', 'Derailed ', 'Aftershock ', 'Antboy ', 'Death in Venice ', 'Skazka o tsare Saltane ', 'Cleanskin ', 'The Count of Monte Cristo ', 'The Frisco Kid ', 'The Mad Genius ', 'The Return of Frank Cannon ', 'La classe de neige ', 'Adult Beginners ', 'The Gambler ', 'Pictures of the Old World ', 'Camp Hell ', 'Dots ', 'Sullivans Banken ', 'The Walking Deceased ', 'Halo 4: Forward Unto Dawn', 'RKO 281 ', 'Movie Crazy ', 'Das singende, klingende BÌ_umchen ', 'Stargate ', 'The Escape Artist', 'Bon appÌ©tit ', 'The Red Mill ', "L'auberge espagnole ", 'Match ', 'David and Bathsheba ', 'Flying Leathernecks ', 'Tales of Halloween ', 'The Old Dark House ', 'Magician Mickey ', 'Cocaine Cowboys: Reloaded ', "Kissin' Cousins ", 'Motforestilling ', "Nobody's Fool ", 'The Office Wife ', 'Alone in the Dark ', 'Heart of Glass ', 'The Veils of Bagdad ', 'The Long and Short of It ', 'Homebodies ', 'Rooster Cogburn ', 'Voyna i mir IV: Pierre Bezukhov ', 'Als je begrijpt wat ik bedoel ', 'El Ì¼ltimo verano de la Boyita ', 'Martial Law ', 'Zebraman ', 'The Brooke Ellison Story ', 'Hedwig and the Angry Inch ', 'Lions for Lambs ', 'Illegally Yours ', 'Saving Sarah Cain ', "The Hitchhiker's Guide to the Galaxy ", '1 1/2 Ritter - Auf der Suche nach der hinreiÌÙenden Herzelinde ', 'Hei yan quan ', "Mike's New Car ", 'I Drink Your Blood ', 'Auk nr 8 ', 'The Mambo Kings ', 'L.A. Story ', 'We of the Never Never ', 'Donkey Punch ', 'Fritt vilt III ', 'Always Outnumbered ', 'Drums Across the River ', 'The Duchess of Langeais ', 'I Always Wanted to Be a Gangster ', 'Elephant ', 'Hell of the Living Dead ', 'Orderers ', 'For the Bible Tells Me So ', 'Skatetown, U.S.A. ', 'Mammoth ', 'Jem and the Holograms ', 'Shattered ', 'The Goods: Live Hard, Sell Hard ', 'The Ghost of Flight 401 ', 'Elvis Has Left the Building ', 'Second Fiddle to a Steel Guitar ', 'Indictment: The McMartin Trial ', 'A Golden Christmas ', 'The Seventh Seal ', 'Pernicious ', 'Crime After Crime ', 'Yo ...
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ', 'VipÌ¬re au poing ', 'Hour of the Gun ', 'Hansel & Gretel ', 'Oy Vey! My Son Is Gay!! ', 'Oslo, 31. august ', 'Love Me ', 'El malvado Carabel ', 'Der Clown ', 'Licks ', 'Chan Is Missing ', 'The Big Blue ', 'Madame Bovary ', 'Borrowed Hearts ', 'The Quiet Room ', 'I 2 pompieri ', "There's Something Wrong with Aunt Diane ", 'No One Dies in Lily Dale ', 'Ernest Goes to Jail ', 'Suffragette ', 'Andron ', 'Sweet Revenge ', 'No Time for Comedy ', 'Subspecies ', 'Mesrine Part 2: Public Enemy #1 ', 'Sparrows Dance ', 'Askari ', 'I Want to Marry Ryan Banks ', 'Human Highway ', 'O.S.S. ', "Fool's Gold ", 'The River and Death ', 'The Case of the Velvet Claws ', 'Dog Park ', 'Tarzan in Manhattan ', 'Marilena de la P7 ', 'Body Language ', 'The Beast from 20,000 Fathoms ', 'The Match ', 'Dance Me Outside ', 'Huang feihong zhi yingxiong you meng ', 'Mosquito Squadron ', 'Derailed ', 'Aftershock ', 'Antboy ', 'Death in Venice ', 'Skazka o tsare Saltane ', 'Cleanskin ', 'The Count of Monte Cristo ', 'The Frisco Kid ', 'The Mad Genius ', 'The Return of Frank Cannon ', 'La classe de neige ', 'Adult Beginners ', 'The Gambler ', 'Pictures of the Old World ', 'Camp Hell ', 'Dots ', 'Sullivans Banken ', 'The Walking Deceased ', 'Halo 4: Forward Unto Dawn', 'RKO 281 ', 'Movie Crazy ', 'Das singende, klingende BÌ_umchen ', 'Stargate ', 'The Escape Artist', 'Bon appÌ©tit ', 'The Red Mill ', "L'auberge espagnole ", 'Match ', 'David and Bathsheba ', 'Flying Leathernecks ', 'Tales of Halloween ', 'The Old Dark House ', 'Magician Mickey ', 'Cocaine Cowboys: Reloaded ', "Kissin' Cousins ", 'Motforestilling ', "Nobody's Fool ", 'The Office Wife ', 'Alone in the Dark ', 'Heart of Glass ', 'The Veils of Bagdad ', 'The Long and Short of It ', 'Homebodies ', 'Rooster Cogburn ', 'Voyna i mir IV: Pierre Bezukhov ', 'Als je begrijpt wat ik bedoel ', 'El Ì¼ltimo verano de la Boyita ', 'Martial Law ', 'Zebraman ', 'The Brooke Ellison Story ', 'Hedwig and the Angry Inch ', 'Lions for Lambs ', 'Illegally Yours ', 'Saving Sarah Cain ', "The Hitchhiker's Guide to the Galaxy ", '1 1/2 Ritter - Auf der Suche nach der hinreiÌÙenden Herzelinde ', 'Hei yan quan ', "Mike's New Car ", 'I Drink Your Blood ', 'Auk nr 8 ', 'The Mambo Kings ', 'L.A. Story ', 'We of the Never Never ', 'Donkey Punch ', 'Fritt vilt III ', 'Always Outnumbered ', 'Drums Across the River ', 'The Duchess of Langeais ', 'I Always Wanted to Be a Gangster ', 'Elephant ', 'Hell of the Living Dead ', 'Orderers ', 'For the Bible Tells Me So ', 'Skatetown, U.S.A. ', 'Mammoth ', 'Jem and the Holograms ', 'Shattered ', 'The Goods: Live Hard, Sell Hard ', 'The Ghost of Flight 401 ', 'Elvis Has Left the Building ', 'Second Fiddle to a Steel Guitar ', 'Indictment: The McMartin Trial ', 'A Golden Christmas ', 'The Seventh Seal ', 'Pernicious ', 'Crime After Crime ', 'Yo ...
# ['The Dirty Dozen: The Fatal Mission ', 'Sobache serdtse ', 'Tin Men ', 'The Trip to Bountiful ', 'Dangerous Liaisons ', 'Bound by Flesh ', '18 comidas ', 'Blume in Love ', "All Tomorrow's Parties ", 'My Own Private Idaho ', 'Manufactured Landscapes ', 'Below Zero ', 'Moe no suzaku ', 'Duvar ', 'The Price of Milk ', 'The Unsinkable Molly Brown ', 'Les maÌ¨tres fous ', 'Amore e rabbia ', 'Tough Guys ', 'Resurrection County ', 'Denise Calls Up ', 'Nova Zembla ', 'The Wedding Planner ', 'YPF ', 'Gunsmith Cats ', 'Indiscreet ', 'Insurgent ', 'How to Lose a Guy in 10 Days ', 'Beware of Mr. Baker ', 'American Pastime ', 'Wanderlust ', 'PoliWood ', 'Full Speed ', 'Mater and the Ghostlight ', 'Road to Yesterday ', 'Total Eclipse ', 'Fragments of an Alms-Film ', 'Blackboards ', 'Scooby-Doo! The Mystery Begins ', 'Birdemic: Shock and Terror ', 'Plymouth Adventure ', 'For Those in Peril ', 'Davy Crockett, Indian Scout ', "The Second Annual 'On Cinema' Oscar Special ", 'Panzehir ', "Porky's ", 'Ki & Ka ', 'Foxfire ', 'Amar te duele ', 'Kirikou et les bÌ»tes sauvages ', 'Two Faces of the Dollar ', 'Lili ', 'Dororo ', "Spencer's Mountain ", 'Return to Horror High ', 'VipÌ¬re au poing ', 'Hour of the Gun ', 'Hansel & Gretel ', 'Oy Vey! My Son Is Gay!! ', 'Oslo, 31. august ', 'Love Me ', 'El malvado Carabel ', 'Der Clown ', 'Licks ', 'Chan Is Missing ', 'The Big Blue ', 'Madame Bovary ', 'Borrowed Hearts ', 'The Quiet Room ', 'I 2 pompieri ', "There's Something Wrong with Aunt Diane ", 'No One Dies in Lily Dale ', 'Ernest Goes to Jail ', 'Suffragette ', 'Andron ', 'Sweet Revenge ', 'No Time for Comedy ', 'Subspecies ', 'Mesrine Part 2: Public Enemy #1 ', 'Sparrows Dance ', 'Askari ', 'I Want to Marry Ryan Banks ', 'Human Highway ', 'O.S.S. ', "Fool's Gold ", 'The River and Death ', 'The Case of the Velvet Claws ', 'Dog Park ', 'Tarzan in Manhattan ', 'Marilena de la P7 ', 'Body Language ', 'The Beast from 20,000 Fathoms ', 'The Match ', 'Dance Me Outside ', 'Huang feihong zhi yingxiong you meng ', 'Mosquito Squadron ', 'Derailed ', 'Aftershock ', 'Antboy ', 'Death in Venice ', 'Skazka o tsare Saltane ', 'Cleanskin ', 'The Count of Monte Cristo ', 'The Frisco Kid ', 'The Mad Genius ', 'The Return of Frank Cannon ', 'La classe de neige ', 'Adult Beginners ', 'The Gambler ', 'Pictures of the Old World ', 'Camp Hell ', 'Dots ', 'Sullivans Banken ', 'The Walking Deceased ', 'Halo 4: Forward Unto Dawn', 'RKO 281 ', 'Movie Crazy ', 'Das singende, klingende BÌ_umchen ', 'Stargate ', 'The Escape Artist', 'Bon appÌ©tit ', 'The Red Mill ', "L'auberge espagnole ", 'Match ', 'David and Bathsheba ', 'Flying Leathernecks ', 'Tales of Halloween ', 'The Old Dark House ', 'Magician Mickey ', 'Cocaine Cowboys: Reloaded ', "Kissin' Cousins ", 'Motforestilling ', "Nobody's Fool ", 'The Office Wife ', 'Alone in the Dark ', 'Heart of Glass ', 'The Veils of Bagdad ', 'The Long and Short of It ', 'Homebodies ', 'Rooster Cogburn ', 'Voyna i mir IV: Pierre Bezukhov ', 'Als je begrijpt wat ik bedoel ', 'El Ì¼ltimo verano de la Boyita ', 'Martial Law ', 'Zebraman ', 'The Brooke Ellison Story ', 'Hedwig and the Angry Inch ', 'Lions for Lambs ', 'Illegally Yours ', 'Saving Sarah Cain ', "The Hitchhiker's Guide to the Galaxy ", '1 1/2 Ritter - Auf der Suche nach der hinreiÌÙenden Herzelinde ', 'Hei yan quan ', "Mike's New Car ", 'I Drink Your Blood ', 'Auk nr 8 ', 'The Mambo Kings ', 'L.A. Story ', 'We of the Never Never ', 'Donkey Punch ', 'Fritt vilt III ', 'Always Outnumbered ', 'Drums Across the River ', 'The Duchess of Langeais ', 'I Always Wanted to Be a Gangster ', 'Elephant ', 'Hell of the Living Dead ', 'Orderers ', 'For the Bible Tells Me So ', 'Skatetown, U.S.A. ', 'Mammoth ', 'Jem and the Holograms ', 'Shattered ', 'The Goods: Live Hard, Sell Hard ', 'The Ghost of Flight 401 ', 'Elvis Has Left the Building ', 'Second Fiddle to a Steel Guitar ', 'Indictment: The McMartin Trial ', 'A Golden Christmas ', 'The Seventh Seal ', 'Pernicious ', 'Crime After Crime ', 'Yo ...

# %%
len(movie_titles)
# Out:
# 476

# %%
# retrieve face detection model fron github and store as 'face_model'

face_model_url = r"https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml"
face_model = wget.download(face_model_url) # store face model in variable
# Out:
# 100% [############################################################################]     908K / 908K

# %%
# define a function that uses face detection model to identify number of faces in each 
# movie poster image and storse the result in a list

"""
Input: list of file pathnames for each movie poster image stored on local drive
Output: list that contains the number of identified faces in each movie poster
"""

def multiProcessing(pathnames, model):
    img_path = [] # create empty list of image paths
    n_faces_list = [] # create empty list of faces
    
    face_classification = cv2.CascadeClassifier(face_model) # load the classifier (models only need to be loaded once)
    
    for path in tqdm(pathnames):              
        pre_image = load_image_from_path(path, color_mode='grayscale')
        gray_image = np.squeeze(pre_image).astype('uint8')
        faces = face_classification.detectMultiScale(gray_image, 1.3, 5) # detect the faces 
        n_faces = len(faces) # get the number of faces       
        n_faces_list.append(n_faces) # add number of faces for each movie poster image to list
        
        path_last_part = os.path.basename(path)
        img_path.append(path_last_part)     
        
    return n_faces_list

# %%
# call the face detection model
# instantiate pathnames variable with all movie poster file pathnames

pathnames = movie_poster_df.Path
n_faces_list = multiProcessing(pathnames, face_model) # store number of faces per image in a list
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=476.0), HTML(value='')))

# %%
# upload the gender identification model and assign it to a variable

gender_url = r"https://github.com/oarriaga/face_classification/raw/master/trained_models/gender_models/gender_mini_XCEPTION.21-0.95.hdf5"
gender_model = wget.download(gender_url)
# Out:
# 100% [############################################################################]     784K / 784K

# %%
# define a function that identifies bounding boxes of faces

def apply_offsets(face_coordinates, offsets):
    """
    Derived from https://github.com/oarriaga/face_classification/blob/
    b861d21b0e76ca5514cdeb5b56a689b7318584f4/src/utils/inference.py#L21
    """
    x, y, width, height = face_coordinates
    x_off, y_off = offsets
    return (x - x_off, x + width + x_off, y - y_off, y + height + y_off)

# %%
# call above function to create bounnding boxes around faces
# use face_model and gender_model to identify gender of faces detected in each movie poster image
# store number of males and females in separate lists

face_classification = cv2.CascadeClassifier(face_model) # load the classifier (models only need to be loaded once)
gender_classifier = load_model(gender_model)

GENDER_OFFSETS = (10, 10)
INPUT_SHAPE_GENDER = gender_classifier.input_shape[1:3]

labels = ['woman', 'man']

n_males_list = []
n_females_list = []

for path in tqdm(pathnames):              
    pre_image = load_image_from_path(path, color_mode='grayscale')
    gray_image = np.squeeze(pre_image).astype('uint8')
    faces = face_classification.detectMultiScale(gray_image, 1.3, 5) # detect the faces
    gender_list = []
    
    for face_coordinates in faces: # using the output of the CascadeClassifier
        x1, x2, y1, y2 = apply_offsets(face_coordinates, GENDER_OFFSETS) # extends the bounding box
        face_img = gray_image[y1:y2, x1:x2] # only get the face 
        try:
            face_img = cv2.resize(face_img, (INPUT_SHAPE_GENDER)) # resize the image
        except:
            continue
        face_img = face_img.astype('float32') / 255.0 # preprocess the image
        face_img = np.expand_dims(face_img, 0) # batch of one
        probas = gender_classifier.predict(face_img) 
        gender_list.append(labels[np.argmax(probas[0])]) # for one image
    count_male = gender_list.count('man')
    count_female = gender_list.count('woman')
    n_males_list.append(count_male)
    n_females_list.append(count_female)
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=476.0), HTML(value='')))

# %%
# loop through all images and use model to retrieve median values for
# red, green and blue colors
# store median values for all images in individual lists

median_r_list = []
median_g_list = []
median_b_list = []

for path in tqdm(pathnames):
    pre_image = load_image_from_path(path, color_mode='grayscale')
    gray_image = np.squeeze(pre_image).astype('uint8')
    color_image = load_image_from_path(path, color_mode='rgb')
    img = Image.fromarray(color_image.astype(np.uint8))
    rgb_array = np.median(img, axis=(0,1)) #create numeric array storing median values 
    median_r_list.append(rgb_array[0]) # append median 'red' values for all images in list
    median_g_list.append(rgb_array[1]) # append median 'green' values for all images in list
    median_b_list.append(rgb_array[2]) # append median 'blue' values for all images in list
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=476.0), HTML(value='')))

# %%
df_movie_posters = pd.DataFrame()

df_movie_posters['Movie'] = movie_titles
df_movie_posters['IMDB_Rating'] = movie_poster_df.IMDB_rating
df_movie_posters['n_Faces'] = n_faces_list 
df_movie_posters['n_Men'] = n_males_list
df_movie_posters['n_Women'] = n_females_list
df_movie_posters['Median_Red'] = median_r_list
df_movie_posters['Median_Green'] = median_g_list
df_movie_posters['Median_Blue'] = median_b_list

df_movie_posters
# Out:
#                                    Movie  IMDB_Rating  n_Faces  n_Men  \
# 0    The Dirty Dozen: The Fatal Mission           5.2        3      3
# 1                       Sobache serdtse           8.9        1      0
# 2                               Tin Men           6.5        0      0
# 3                 The Trip to Bountiful           7.0        1      1
# 4                    Dangerous Liaisons           7.7        1      0
# ..                                   ...          ...      ...    ...
# 471                              Fallen           6.7        1      0
# 472                        Long Way Down          8.4        2      2
# 473                      The AristoCats           7.1        0      0
# 474               Kung Fu Panda Holiday           6.9        0      0
# 475                    A Letter to Elia           7.6        1      1
#
#      n_Women  Median_Red  Median_Green  Median_Blue
# 0          0        76.0          74.0         36.0
# 1          1       170.0          94.0         61.0
# 2          0       207.0         189.0        155.0
# 3          0       222.0         219.0        196.0
# 4          1       110.0          48.0         24.0
# ..       ...         ...           ...          ...
# 471        1       179.0          94.0         28.0
# 472        0       136.0         137.0        154.0
# 473        0       164.0          91.0         83.0
# 474        0        99.0         130.0        154.0
# 475        0       105.0          26.0         30.0
#
# [476 rows x 8 columns]

# %%
df_movie_posters.to_csv("MovieDF.csv", encoding='utf-8', index=False)
