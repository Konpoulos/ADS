# %%
import pandas as pd
import numpy as np
import csv

# %%
df=pd.read_csv('movies.csv')

# %%
merged = pd.merge(etem, goal, left_on='id', right_on='matchid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-7d278d2f6e57> in <module>
# ----> 1 merged = pd.merge(etem, goal, left_on='id', right_on='matchid')
#
# NameError: name 'etem' is not defined

# %%
etem=pd.read_csv('etem.csv', encoding = "ISO-8859-1")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-92-57b09e46aeb3> in <module>
# ----> 1 etem=pd.read_csv('etem.csv', encoding = "ISO-8859-1")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
countries = ['Armenia', "Azerbaijan", "Russia", "Georgia", "Turkey"]

# %%
others = sum(world['area'][world['name']== 'Armenia'])
others
# Out:
# 29743

# %%
europe = sum(world['area'][world['continent']=='Europe'])
europe
# Out:
# 8714329

# %%
others = sum(world['area'][world['name'].isin(countries)])

# %%
europe+others
# Out:
# 26809176

# %%
game=pd.read_csv('game.csv', encoding = "ISO-8859-1")
goal=pd.read_csv('goal.csv', encoding = "ISO-8859-1")
game.head()
goal.head()
# Out:
#    matchid teamid                player  gtime
# 0     1001    POL    Robert Lewandowski     17
# 1     1001    GRE  Dimitris Salpingidis     51
# 2     1002    RUS          Alan Dzagoev     15
# 3     1002    RUS        Roman Shirokov     24
# 4     1002    CZE          Václav Pilar     52

# %%
merged=pd.merge(game,goal,left_on='id',right_on='matchid')
merged
# Out:
#       id      mdate                              stadium team1 team2  matchid  \
# 0   1001   8-Jun-12             National Stadium, Warsaw   POL   GRE     1001
# 1   1001   8-Jun-12             National Stadium, Warsaw   POL   GRE     1001
# 2   1002   8-Jun-12            Stadion Miejski (Wroclaw)   RUS   CZE     1002
# 3   1002   8-Jun-12            Stadion Miejski (Wroclaw)   RUS   CZE     1002
# 4   1002   8-Jun-12            Stadion Miejski (Wroclaw)   RUS   CZE     1002
# ..   ...        ...                                  ...   ...   ...      ...
# 71  1030  28-Jun-12             National Stadium, Warsaw   GER   ITA     1030
# 72  1031   1-Jul-12  Olimpiyskiy National Sports Complex   ESP   ITA     1031
# 73  1031   1-Jul-12  Olimpiyskiy National Sports Complex   ESP   ITA     1031
# 74  1031   1-Jul-12  Olimpiyskiy National Sports Complex   ESP   ITA     1031
# 75  1031   1-Jul-12  Olimpiyskiy National Sports Complex   ESP   ITA     1031
#
# ...

# %%
merged[['player','stadium']][merged['teamid']=='GER']
# Out:
#             player                   stadium
# 15     Mario Gómez                Arena Lviv
# 21     Mario Gómez          Metalist Stadium
# 22     Mario Gómez          Metalist Stadium
# 27  Lukas Podolski                Arena Lviv
# 29     Lars Bender                Arena Lviv
# 61    Philipp Lahm          PGE Arena Gdansk
# 63    Sami Khedira          PGE Arena Gdansk
# 64  Miroslav Klose          PGE Arena Gdansk
# 65      Marco Reus          PGE Arena Gdansk
# 71      Mesut Özil  National Stadium, Warsaw

# %%
merged.loc[:,['player', 'teamid', 'stadium']][(((merged['team1'] == 'FRA') | (merged['team2'] == 'FRA')) & (merged['teamid'] != 'FRA') & (merged['stadium'] == 'Donbass Arena'))]
# Out:
#             player teamid        stadium
# 45  Joleon Lescott    ENG  Donbass Arena
# 67     Xabi Alonso    ESP  Donbass Arena
# 68     Xabi Alonso    ESP  Donbass Arena

# %%
columns = list(world.columns) # put all columns to make code simple

world_2 = world[world[columns].notnull()]

# %%
T AND F
# Out:
#   File "<ipython-input-44-5d5fb775be0d>", line 1
#     T AND F
#         ^
# SyntaxError: invalid syntax

# %%
TRUE & FALSE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-c61f22c1822b> in <module>
# ----> 1 TRUE & FALSE
#
# NameError: name 'TRUE' is not defined

# %%
bbc=pd.read_csv('bbc.csv', encoding = "ISO-8859-1")

# %%
world=pd.read_csv('world.csv', encoding = "ISO-8859-1")

# %%
bbc['name'][~bbc['name'].isin (world['name'])]
# Out:
# 21                        Bosnia-Hercegovina
# 27                                     Burma
# 44              Democratic Republic of Congo
# 49                                East Timor
# 59     Former Yugoslav Republic of Macedonia
# 80        Israel and Palestinian territories
# 82                               Ivory Coast
# 109                               Micronesia
# 134                        Republic of Congo
# 140                    Sao Tome and Principe
# 143                    Serbia and Montenegro
# 155                       St Kitts and Nevis
# 156                                 St Lucia
# 157            St Vincent and the Grenadines
# 159                                  Surinam
# 168                               The Gambia
# 169                             The Maldives
# 170                          The Netherlands
# 171                          The Philippines
# 183                 United States of America
# 187                                  Vatican
# ...

# %%
sum(bbc['population']<150000)
# Out:
# 17

# %%
nobel=pd.read_csv('nobel.csv', encoding = "ISO-8859-1")

# %%
world=pd.read_csv('world.csv', encoding = "ISO-8859-1")

# %%
nobel['winner'][nobel['subject']=='Physics'].count()
# Out:
# 222

# %%
world.isnull().sum()
# Out:
# name          0
# continent     0
# area          0
# population    0
# gdp           6
# capital       1
# tld           0
# flag          0
# dtype: int64

# %%
df_w = pd.read_csv(filepath_or_buffer = 'world.csv', delimiter=',', 
                 doublequote=True, quotechar='"',na_values = ['na', '-', '.', ''], 
                 quoting=csv.QUOTE_ALL, encoding = "ISO-8859-1")
df_w
# Out:
#             name      continent     area  population           gdp  \
# 0    Afghanistan           Asia   652230    25500100  2.036400e+10
# 1        Albania         Europe    28748     2821977  1.204400e+10
# 2        Algeria         Africa  2381741    38700000  2.070210e+11
# 3        Andorra         Europe      468       76098  3.222000e+09
# 4         Angola         Africa  1246700    19183590  1.163080e+11
# ..           ...            ...      ...         ...           ...
# 190    Venezuela  South America   916445    28946101  3.824240e+11
# 191      Vietnam           Asia   331212    89708900  1.558200e+11
# 192        Yemen           Asia   527968    25235000  3.283100e+10
# 193       Zambia         Africa   752612    15023315  2.149000e+10
# 194     Zimbabwe         Africa   390757    13061239  9.802000e+09
#
#               capital  tld                                               flag
# 0               Kabul  .af  //upload.wikimedia.org/wikipedia/commons/9/9a/...
# ...

# %%
(df_w['population'][df_w['continent'] == 'Europe']).sum()
# Out:
# 610261850

# %%
# read the table game.csv
df_game = pd.read_csv(filepath_or_buffer = 'game.csv', delimiter=',', 
                 doublequote=True, quotechar='"',na_values = ['na', '-', '.', ''], 
                 quoting=csv.QUOTE_ALL, encoding = "ISO-8859-1")

# %%
# read the table game.csv
df_game = pd.read_csv(filepath_or_buffer = 'goal.csv', delimiter=',', 
                 doublequote=True, quotechar='"',na_values = ['na', '-', '.', ''], 
                 quoting=csv.QUOTE_ALL, encoding = "ISO-8859-1")

# %%
merged=pd.merge(game,goal,left_on='id',right_on='matchid')

# %%
merged[['player', 'teamid', 'stadium']][(((merged['team1'] == 'FRA') | (merged['team2'] == 'FRA')) & (merged['teamid'] != 'FRA') & (merged['stadium'] == 'Donbass Arena'))]
# Out:
#             player teamid        stadium
# 45  Joleon Lescott    ENG  Donbass Arena
# 67     Xabi Alonso    ESP  Donbass Arena
# 68     Xabi Alonso    ESP  Donbass Arena

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df[df.columns[[5,7,9]]][:]
# Out:
#       actor_3_facebook_likes  actor_1_facebook_likes  \
# 0                      855.0                  1000.0
# 1                     1000.0                 40000.0
# 2                      161.0                 11000.0
# 3                    23000.0                 27000.0
# 4                        NaN                   131.0
# ...                      ...                     ...
# 3995                     3.0                   118.0
# 3996                     0.0                     0.0
# 3997                   128.0                   968.0
# 3998                   442.0                 10000.0
# 3999                     6.0                    24.0
#
#                                genres
# 0     Action|Adventure|Fantasy|Sci-Fi
# 1            Action|Adventure|Fantasy
# 2           Action|Adventure|Thriller
# 3                     Action|Thriller
# 4                         Documentary
# ...                               ...
# 3995           Action|Sci-Fi|Thriller
# ...

# %%
df.loc[df['content_rating'] == 'PG‐13', ['actor_1_facebook_likes',
'actor_3_facebook_likes', 'budget']]
# Out:
# Empty DataFrame
# Columns: [actor_1_facebook_likes, actor_3_facebook_likes, budget]
# Index: []

# %%
df.iloc[:,5:10]
# Out:
#       actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                      855.0  Joel David Moore                  1000.0
# 1                     1000.0     Orlando Bloom                 40000.0
# 2                      161.0      Rory Kinnear                 11000.0
# 3                    23000.0    Christian Bale                 27000.0
# 4                        NaN        Rob Walker                   131.0
# ...                      ...               ...                     ...
# 3995                     3.0   Steve Diasparra                   118.0
# 3996                     0.0    Amanda Kearsan                     0.0
# 3997                   128.0       Sean Whalen                   968.0
# 3998                   442.0       Lena Dunham                 10000.0
# 3999                     6.0       Jason Evers                    24.0
#
#             gross                           genres
# 0     760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df['director_facebook_likes'].sum()
# Out:
# 2954493.0

# %%
df.count('NaN')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-3ecb3e3562d7> in <module>
# ----> 1 df.count('NaN')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in count(self, axis, level, numeric_only)
#    7782         Myla      1
#    7783         """
# -> 7784         axis = self._get_axis_number(axis)
#    7785         if level is not None:
#    7786             return self._count_level(level, axis=axis, numeric_only=numeric_only)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     405             except KeyError:
#     406                 pass
# --> 407         raise ValueError(f"No axis named {axis} for object type {cls}")
#     408
#     409     @classmethod
#
# ValueError: No axis named NaN for object type <class 'pandas.core.frame.DataFrame'>

# %%
df_game[(df_game['team1']=="NED" )| (df_game['team2']=="NED" )]
# Out:
#       id      mdate           stadium team1 team2
# 6   1007   9-Jun-12  Metalist Stadium   NED   DEN
# 9   1010  13-Jun-12  Metalist Stadium   NED   GER
# 10  1011  17-Jun-12  Metalist Stadium   POR   NED

# %%
import psycopg2
conn = psycopg2.connect(database='dvdrental', user='postgres', host= '127.0.0.1', port=5432)
cursor = conn.cursor()

# %%
cursor.execute("SELECT table_name FROM information_schema.tables WHERE table_schema='public' AND table_type='BASE TABLE';")

# %%
pd.DataFrame(cursor,columns=['name'])
# Out:
#              name
# 0           actor
# 1           store
# 2         address
# 3        category
# 4            city
# 5         country
# 6        customer
# 7      film_actor
# 8   film_category
# 9       inventory
# 10       language
# 11         rental
# 12          staff
# 13        payment
# 14           film

# %%
dd1 = pd.DataFrame( { 'id': ['1', '2', '3', '4', '5'], 'Feature1': ['A', 'C', 'E', 'G', 'I'],'Feature2':['B', 'D', 'F' , 'H', 'J']})

# %%
dd2 = pd.DataFrame( { 'id': ['1', '2', '6', '7', '8'], 'Feature1': ['A', 'C', 'O', 'Q', 'S'],'Feature2': ['B', 'D', 'P', 'R', 'T']})

# %%
union_df = pd.concat([dd1, dd2])
union_df
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J
# 0  1        A        B
# 1  2        C        D
# 2  6        O        P
# 3  7        Q        R
# 4  8        S        T

# %%
union_df2 = pd.concat([dd1, dd2],axis=1)
union_df2
# Out:
#   id Feature1 Feature2 id Feature1 Feature2
# 0  1        A        B  1        A        B
# 1  2        C        D  2        C        D
# 2  3        E        F  6        O        P
# 3  4        G        H  7        Q        R
# 4  5        I        J  8        S        T
